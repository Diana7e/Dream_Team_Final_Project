# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
testing = pd.read_csv("cleaned_data/Predictions.csv")

df = pd.DataFrame(testing)

df.head(50)
# Out:
#     index  Prediction   Actual
# 0   12935   796705.00   763000
# 1   16125  4000930.00  3675000
# 2    2553   363847.51   366000
# 3     849   610000.00   594900
# 4   49062   135939.00   169000
# 5   23066   735240.00   700000
# 6    3659   708541.25   724110
# 7    6265   974990.00   930000
# 8   13190   938715.00   890000
# 9   10827   135938.86   169000
# 10  18682   836233.82   814000
# 11  13550  1674672.06  1585000
# 12  31399   606990.00   639000
# 13   9369   273989.50   285000
# 14  20342  3499050.00  3200000
# 15   4222   907531.00   870000
# 16   5784   361994.00   380000
# 17   8409   675539.46   636000
# 18  19444  1252235.00  1195000
# 19  28457   192090.50   235000
# 20   8724   910021.00   889000
# 21  28508   574084.20   585000
# 22  25920   736717.95   740000
# 23  12404  1036748.00   987000
# 24  11722   940261.79   900000
# 25  52433   257524.20   286000
# 26   9143  1264391.25  1200000
# 27  38206   287704.50   321000
# 28  51225    92479.49   138000
# ...

# %%
df['Variance'] = df['Prediction'] - df['Actual']
df['% Variance'] = (df['Variance']/df['Prediction'])*100
df['% Variance'] = df['% Variance'].map('{:.2f}%'.format)
df.head()
# Out:
#    index  Prediction   Actual   Variance % Variance
# 0  12935   796705.00   763000   33705.00      4.23%
# 1  16125  4000930.00  3675000  325930.00      8.15%
# 2   2553   363847.51   366000   -2152.49     -0.59%
# 3    849   610000.00   594900   15100.00      2.48%
# 4  49062   135939.00   169000  -33061.00    -24.32%
